# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
import json

# %%
img_size = (224, 224)
batch_size = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

train_data = datagen.flow_from_directory(
    "../dataset",
    target_size=img_size,
    batch_size=batch_size,
    class_mode="categorical",
    subset="training"
)

val_data = datagen.flow_from_directory(
    "../dataset",
    target_size=img_size,
    batch_size=batch_size,
    class_mode="categorical",
    subset="validation"
)
# Out:
# Found 1891 images belonging to 15 classes.
# Found 468 images belonging to 15 classes.

# %%
base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.5)(x)

output = Dense(train_data.num_classes, activation="softmax")(x)

model = Model(base_model.input, output)

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
model.fit(train_data, validation_data=val_data, epochs=15)

model.save("../model/crop_disease_model.h5")

with open("../model/class_indices.json", "w") as f:
    json.dump(train_data.class_indices, f)
# Out:
# d:\entire\multi_crop_flask\venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 271s 4s/step - accuracy: 0.4907 - loss: 1.5414 - val_accuracy: 0.6111 - val_loss: 1.0023
# Epoch 2/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 215s 4s/step - accuracy: 0.6848 - loss: 0.9388 - val_accuracy: 0.6667 - val_loss: 0.9771
# Epoch 3/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 203s 3s/step - accuracy: 0.7176 - loss: 0.7904 - val_accuracy: 0.6838 - val_loss: 0.8955
# Epoch 4/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 207s 3s/step - accuracy: 0.7525 - loss: 0.6896 - val_accuracy: 0.6731 - val_loss: 0.9060
# Epoch 5/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 211s 4s/step - accuracy: 0.7636 - loss: 0.6648 - val_accuracy: 0.7051 - val_loss: 0.8635
# Epoch 6/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 197s 3s/step - accuracy: 0.7869 - loss: 0.6004 - val_accuracy: 0.6859 - val_loss: 0.8551
# Epoch 7/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 216s 4s/step - accuracy: 0.7932 - loss: 0.5733 - val_accuracy: 0.6774 - val_loss: 0.8926
# Epoch 8/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 208s 3s/step - accuracy: 0.8006 - loss: 0.5765 - val_accuracy: 0.6774 - val_loss: 0.9457
# Epoch 9/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 286s 5s/step - accuracy: 0.8038 - loss: 0.5404 - val_accuracy: 0.6752 - val_loss: 0.9426
# Epoch 10/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 244s 4s/step - accuracy: 0.8128 - loss: 0.5240 - val_accuracy: 0.6966 - val_loss: 0.9422
# Epoch 11/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - accuracy: 0.8197 - loss: 0.4794 - val_accuracy: 0.6944 - val_loss: 0.9737
# Epoch 12/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 217s 4s/step - accuracy: 0.8228 - loss: 0.4690 - val_accuracy: 0.7030 - val_loss: 0.9237
# Epoch 13/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 217s 4s/step - accuracy: 0.8366 - loss: 0.4455 - val_accuracy: 0.7222 - val_loss: 1.0430
# Epoch 14/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 261s 4s/step - accuracy: 0.8419 - loss: 0.4416 - val_accuracy: 0.7158 - val_loss: 0.9004
# Epoch 15/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 270s 5s/step - accuracy: 0.8414 - loss: 0.4231 - val_accuracy: 0.7329 - val_loss: 0.8939
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
